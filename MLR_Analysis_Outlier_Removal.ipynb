# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/water-quality-cleaned.csv")

# %%
df.head()
# Out:
#          pH        DO  Conductivity  Temperature   Total_N   Total_P  \
# 0  0.903448 -0.121627      0.004939     0.926817 -0.911018 -0.015317
# 1  0.783984 -0.858708     -0.052245     0.753946 -0.363770 -0.015317
# 2  1.103978  0.020234     -0.106052     1.203410 -0.363770 -0.015317
# 3  0.254928 -0.518440     -0.135834     0.995965 -0.034853 -0.015317
# 4  0.476790  0.215664     -0.035970     0.719372 -0.596279 -0.015317
#
#     Nitrate  Orthophosphate  Year  Month  Season
# 0  0.005578        0.029471  2015      8  Summer
# 1  0.005578        0.046118  2015      8  Summer
# 2  0.005578        0.025256  2015      8  Summer
# 3  0.005578        0.056022  2015      8  Summer
# 4  0.005578        0.039585  2015      8  Summer

# %%
#Missingness summary to confirm correct, cleaned, dataset is being used
missing_info = pd.DataFrame({
    "Missing Count": df.isna().sum(),
    "Missing %": (df.isna().sum() / len(df) * 100).round(2)
}).sort_values(by="Missing %", ascending=False)

print(missing_info)
# Out:
#                 Missing Count  Missing %
# pH                          0        0.0
# DO                          0        0.0
# Conductivity                0        0.0
# Temperature                 0        0.0
# Total_N                     0        0.0
# Total_P                     0        0.0
# Nitrate                     0        0.0
# Orthophosphate              0        0.0
# Year                        0        0.0
# Month                       0        0.0
# Season                      0        0.0

# %%
#checking for outliers
def plot_boxplot(df, ft):
    df.boxplot(column=[ft])
    plt.grid(False)
    plt.show()

# %%
plot_boxplot(df, 'DO')

# %%
plot_boxplot(df, 'pH')

# %%
plot_boxplot(df, 'Conductivity')

# %%
plot_boxplot(df, 'Temperature')

# %%
plot_boxplot(df, 'Total_N')

# %%
plot_boxplot(df, 'Total_P')

# %%
plot_boxplot(df, 'Nitrate')

# %%
plot_boxplot(df, 'Orthophosphate')

# %%
#Outlier removal
from sklearn.metrics import DistanceMetric as DM
from scipy.stats import f
from scipy.spatial.distance import mahalanobis

# %%
#use only numeric columns for covariance calculation
numeric_df = df.select_dtypes(include=np.number)

inv_cov = pd.DataFrame(np.linalg.pinv(numeric_df.cov().values), columns=numeric_df.cov().columns, index=numeric_df.cov().index)

x=numeric_df.values.tolist()
xbar=numeric_df.mean().tolist()

n=len(x)
k=len(x[0])

Hotvalue = (k * (n - 1) / (n - k))*f.ppf(0.95, k, n - k)

print(Hotvalue)
# Out:
# 18.30883689526194

# %%
for i in range(0,len(x)):
  df.loc[df.index == i, 'hotelling']=(n*k)*mahalanobis(x[i], xbar, inv_cov)**2/(k*(n-k))
  df.loc[df.index == i, 'critical value']=Hotvalue

# %%
x=np.array(df.index.tolist())
y1=np.array(df['hotelling'])
f = plt.figure()

ax = f.add_subplot(111)


plt.plot(x, y1)
plt.axhline(y=df['hotelling'].mean())
plt.axhline(y=Hotvalue,color='r')

# %%
#removing outliers
df_clean = df[df['hotelling'] <= df['critical value'].iloc[0]].copy()
df_outliers = df[df['hotelling'] > df['critical value'].iloc[0]].copy()

print(df_clean.shape)
print(df.shape)
print(df_outliers.shape)
# Out:
# (138981, 13)
# (144056, 13)
# (5075, 13)

# %%
output_path = "water-quality-nooutliers.csv"
df_clean.to_csv(output_path, index=False)

# %%
plot_boxplot(df_clean, 'DO')

# %%
plt.scatter(df_clean["Temperature"], df_clean["DO"], alpha=0.3)
plt.title("Temperature vs Dissolved Oxygen (field)")
plt.xlabel("Temperature (°C)")
plt.ylabel("Dissolved Oxygen (mg/L)")
plt.show()

# %%
plt.scatter(df_clean["Temperature"], df_clean["Total_N"], alpha=0.3)
plt.title("Temperature vs Nitrogen Levels")
plt.xlabel("Temperature (°C)")
plt.ylabel("Nitrogen Levels (mg/L)")
plt.show()

# %%
plt.scatter(df_clean["Temperature"], df_clean["Total_P"], alpha=0.3)
plt.title("Temperature vs Phosphorus Levels")
plt.xlabel("Temperature (°C)")
plt.ylabel("Phosphorus Levels (mg/L)")
plt.show()

# %%
df_clean['Seasons'] = df_clean['Season'].map({
    'Winter': 1,
    'Spring': 2,
    'Summer': 3,
    'Autumn': 4
}) #makes seasons into numerical form

# Select columns for correlation
cols_for_corr = [
    'pH', 'DO', 'Conductivity', 'Temperature',
    'Total_N', 'Total_P', 'Orthophosphate', 'Nitrate',
    'Year', 'Month', 'Seasons'
]

plt.figure(figsize=(10,8))
sns.heatmap(df_clean[cols_for_corr].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.boxplot(x="Season", y="pH", data=df_clean)
plt.title("Seasonal Variation in pH (field)")
plt.xlabel("Season (1=Winter, 2=Spring, 3=Summer, 4=Fall)")
plt.ylabel("pH")
plt.show()

# %%
sns.boxplot(x="Season", y="Temperature", data=df_clean)
plt.title("Seasonal Variation in Temperature")
plt.xlabel("Season (1=Winter, 2=Spring, 3=Summer, 4=Fall)")
plt.ylabel("Temperature (°C)")
plt.show()

# %%
sns.boxplot(x="Season", y="DO", data=df_clean)
plt.title("Seasonal Variation in Dissolved Oxygen (field)")
plt.xlabel("Season (1=Winter, 2=Spring, 3=Summer, 4=Fall)")
plt.ylabel("Dissolved Oxygen (mg/L)")
plt.show()

# %%
yearly_temp = df_clean.groupby("Year")["Temperature"].mean()

plt.plot(yearly_temp.index, yearly_temp.values, marker="o")
plt.title("Average Temperature by Year")
plt.xlabel("Year")
plt.ylabel("Temperature (°C)")
plt.grid(True)
plt.show()

# %%
yearly_do = df_clean.groupby("Year")["DO"].mean()

plt.plot(yearly_do.index, yearly_do.values, marker="o", color="green")
plt.title("Average Dissolved Oxygen by Year")
plt.xlabel("Year")
plt.ylabel("Dissolved Oxygen (mg/L)")
plt.grid(True)
plt.show()

# %%
yearly_do = df_clean.groupby("Year")["Total_N"].mean()

plt.plot(yearly_do.index, yearly_do.values, marker="o", color="purple")
plt.title("Average Total Nitrogen by Year")
plt.xlabel("Year")
plt.ylabel("Total Nitrogen (mg/L)")
plt.grid(True)
plt.show()

# %%
yearly = df_clean.groupby("Year")[["Temperature", "DO"]].mean()

fig, ax1 = plt.subplots(figsize=(10,5))

# Temperature (left axis)
ax1.plot(yearly.index, yearly["Temperature"], color="red", marker="o", label="Temperature (°C)")
ax1.set_xlabel("Year")
ax1.set_ylabel("Temperature (°C)", color="red")
ax1.tick_params(axis="y", labelcolor="red")

# Dissolved Oxygen (right axis)
ax2 = ax1.twinx()
ax2.plot(yearly.index, yearly["DO"], color="blue", marker="o", label="Dissolved Oxygen (mg/L)")
ax2.set_ylabel("Dissolved Oxygen (mg/L)", color="blue")
ax2.tick_params(axis="y", labelcolor="blue")

plt.title("Temperature vs Dissolved Oxygen (Yearly Averages)")
plt.grid(True)
plt.show()

# %%
yearly = df_clean.groupby("Year")[["Temperature", "Total_N", "Total_P"]].mean()

plt.figure(figsize=(10,5))
plt.plot(yearly.index, yearly["Temperature"], marker="o", label="Temperature (°C)", color="red")
plt.plot(yearly.index, yearly["Total_N"], marker="o", label="Total Nitrogen (mg/L)", color="blue")
plt.plot(yearly.index, yearly["Total_P"], marker="o", label="Total Phosphorus (mg/L)", color="purple")

plt.title("Yearly Averages of Temperature, Total Nitrogen, and Total Phosphorus")
plt.xlabel("Year")
plt.ylabel("Values")
plt.legend()
plt.grid(True)
plt.show()

# %%
yearly = df_clean.groupby("Year")[["Total_N", "Total_P"]].mean()

fig, ax1 = plt.subplots(figsize=(10,5))

# Nitrogen (left axis)
ax1.plot(yearly.index, yearly["Total_N"], color="red", marker="o", label="Total Nitrogen")
ax1.set_xlabel("Year")
ax1.set_ylabel("Total Nitrogen", color="red")
ax1.tick_params(axis="y", labelcolor="red")

# Phosphorus (right axis)
ax2 = ax1.twinx()
ax2.plot(yearly.index, yearly["Total_P"], color="blue", marker="o", label="Total Phosphorus")
ax2.set_ylabel("Total Phosphorus", color="blue")
ax2.tick_params(axis="y", labelcolor="blue")

plt.title("Total Nitrogen VS Total Phosphorus (Yearly Averages)")
plt.grid(True)
plt.show()

# %%
#MLR analysis
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.stattools import durbin_watson

# %%
target = 'Temperature'
predictors = [
    'pH', 'DO', 'Conductivity',
    'Total_N', 'Total_P', 'Orthophosphate', 'Nitrate',]

# %%
#OLS Regression using only chemical indicators, excluding year, month and seasons
X = sm.add_constant(df_clean[predictors])
y = df_clean[target]
mlr = sm.OLS(y, X).fit()
print(mlr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Temperature   R-squared:                       0.519
# Model:                            OLS   Adj. R-squared:                  0.519
# Method:                 Least Squares   F-statistic:                 2.146e+04
# Date:                Mon, 01 Dec 2025   Prob (F-statistic):               0.00
# Time:                        13:09:18   Log-Likelihood:            -1.0149e+05
# No. Observations:              138981   AIC:                         2.030e+05
# Df Residuals:                  138973   BIC:                         2.031e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0348      0.002     20.027      0.000       0.031       0.038
# pH                 0.5112      0.002    326.630      0.000       0.508       0.514
# DO                -0.4530      0.002   -253.143      0.000      -0.457      -0.450
# Conductivity       0.2806      0.007     42.995      0.000       0.268       0.293
# Total_N           -0.0954      0.002    -46.879      0.000      -0.099      -0.091
# Total_P            0.0907      0.117      0.777      0.437      -0.138       0.319
# Orthophosphate     0.5438      0.029     18.996      0.000       0.488       0.600
# Nitrate           -0.0109      0.024     -0.451      0.652      -0.058       0.036
# ==============================================================================
# Omnibus:                     4263.447   Durbin-Watson:                   0.687
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6212.225
# Skew:                           0.320   Prob(JB):                         0.00
# Kurtosis:                       3.814   Cond. No.                         97.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df_clean.head()
# Out:
#          pH        DO  Conductivity  Temperature   Total_N   Total_P  \
# 0  0.903448 -0.121627      0.004939     0.926817 -0.911018 -0.015317
# 1  0.783984 -0.858708     -0.052245     0.753946 -0.363770 -0.015317
# 2  1.103978  0.020234     -0.106052     1.203410 -0.363770 -0.015317
# 3  0.254928 -0.518440     -0.135834     0.995965 -0.034853 -0.015317
# 4  0.476790  0.215664     -0.035970     0.719372 -0.596279 -0.015317
#
#     Nitrate  Orthophosphate  Year  Month  Season  hotelling  critical value  \
# 0  0.005578        0.029471  2015      8  Summer   2.905416       18.308837
# 1  0.005578        0.046118  2015      8  Summer   3.379854       18.308837
# 2  0.005578        0.025256  2015      8  Summer   3.112905       18.308837
# 3  0.005578        0.056022  2015      8  Summer   2.261796       18.308837
# 4  0.005578        0.039585  2015      8  Summer   2.135104       18.308837
#
#    Seasons
# 0        3
# 1        3
# 2        3
# 3        3
# 4        3

# %%
target = 'Temperature'
predictors = [
    'pH', 'DO', 'Conductivity', 'Total_N', 'Total_P', 'Orthophosphate', 'Nitrate',
    'Year', 'Month', 'Seasons']

# %%
#OLS Regression using all predictors, including year, month and seasons
X = sm.add_constant(df_clean[predictors])
y = df_clean[target]
mlr = sm.OLS(y, X).fit()
print(mlr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Temperature   R-squared:                       0.573
# Model:                            OLS   Adj. R-squared:                  0.573
# Method:                 Least Squares   F-statistic:                 1.867e+04
# Date:                Mon, 01 Dec 2025   Prob (F-statistic):               0.00
# Time:                        13:25:09   Log-Likelihood:                -93233.
# No. Observations:              138981   AIC:                         1.865e+05
# Df Residuals:                  138970   BIC:                         1.866e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.2467      0.243     -1.016      0.310      -0.723       0.229
# pH                 0.4702      0.002    311.538      0.000       0.467       0.473
# DO                -0.3394      0.002   -178.574      0.000      -0.343      -0.336
# Conductivity       0.2266      0.006     36.748      0.000       0.214       0.239
# Total_N           -0.0481      0.002    -24.579      0.000      -0.052      -0.044
# Total_P            0.2428      0.112      2.176      0.030       0.024       0.461
# Orthophosphate     0.3109      0.027     11.499      0.000       0.258       0.364
# Nitrate            0.0003      0.023      0.011      0.991      -0.044       0.045
# Year              -0.0001      0.000     -1.046      0.295      -0.000       0.000
# Month              0.0111      0.001     20.337      0.000       0.010       0.012
# Seasons            0.1709      0.002     98.074      0.000       0.168       0.174
# ==============================================================================
# Omnibus:                     5161.721   Durbin-Watson:                   0.682
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7655.540
# Skew:                           0.364   Prob(JB):                         0.00
# Kurtosis:                       3.890   Cond. No.                     3.85e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.85e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#residuals
fitted = mlr.fittedvalues
resid = mlr.resid

plt.figure()
plt.scatter(fitted, resid, s=30)
plt.axhline(0, linewidth=1)
plt.xlabel("Fitted values"); plt.ylabel("Residuals")
plt.title("Residuals vs Fitted (MLR)"); plt.show()

# %%
#VIF
# we expect year, month and seasons to be highly correlated with temperature so
# they understandably have high VIF values
X_vif = df_clean[predictors].values
vif_vals = [variance_inflation_factor(X_vif, i) for i in range(X_vif.shape[1])]
pd.DataFrame({"predictor": predictors, "VIF": np.round(vif_vals, 2)})
# Out:
#         predictor    VIF
# 0              pH   1.32
# 1              DO   1.75
# 2    Conductivity   1.13
# 3         Total_N   1.25
# 4         Total_P   2.78
# 5  Orthophosphate   1.94
# 6         Nitrate   1.01
# 7            Year  11.99
# 8           Month   9.98
# 9         Seasons  15.39
